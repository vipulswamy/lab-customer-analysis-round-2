# %%
import pandas as pd  
import numpy as np

# %%
file1 = pd.read_excel('marketing_customer_analysis.xlsx')
display(file1)
column_names = file1.columns
column_names
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 1             1.0  KX64629  California              2228.525238       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
column_names = file1.columns
data_coloumn = pd.DataFrame(columns=column_names)
data_coloumn
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Vehicle Type]
# Index: []
#
# [0 rows x 26 columns]

# %%
data = pd.DataFrame(file1)
display(data)
data.shape
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 1             1.0  KX64629  California              2228.525238       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#before cleaing lets quickly analyse the spaces before we standardise anything
display(data.head(20))
display(data.tail(20))
# Out:
#     Serial Number Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# 5               5  HO81102         NaN              4745.181764      NaN
# 6               6  IW72280  California              5035.035257       No
# 7               7  IH64929  California              4956.247235       No
# 8               8  FM55990  California              5989.773931      Yes
# 9               9  QX31376      Oregon             17114.328150       No
# 10             10  HG93801     Arizona              5154.764074       No
# 11             11  GE63585         NaN              2420.711888      NaN
# ...

# %%
# rename the unnamed coloumn to serial 
data.rename( columns={'Unnamed: 0':'Serial Number'}, inplace=True )
data
# Out:
#        Serial Number Customer       State  Customer Lifetime Value Response  \
# 0                0.0  DK49336     Arizona              4809.216960       No
# 1                1.0  KX64629  California              2228.525238       No
# 2                2.0  LZ68649  Washington             14947.917300       No
# 3                3.0  XL78013      Oregon             22332.439460      Yes
# 4                4.0  QA50777      Oregon              9025.067525       No
# ...              ...      ...         ...                      ...      ...
# 10905        10905.0  FE99816      Nevada             15563.369440       No
# 10906        10906.0  KX53892      Oregon              5259.444853       No
# 10907        10907.0  TL39050     Arizona             23893.304100       No
# 10908        10908.0  WA60547  California             11971.977650       No
# 10909        10909.0  IV32877         NaN              6857.519928      NaN
#
# ...

# %%
# convert the tables to proper numeric values
# convert column "serial number" of DataFrame to numeric
data["Serial Number"] = pd.to_numeric(data["Serial Number"])
data['Serial Number'] = data['Serial Number'].astype('int')
data
# Out:
#        Serial Number Customer       State  Customer Lifetime Value Response  \
# 0                  0  DK49336     Arizona              4809.216960       No
# 1                  1  KX64629  California              2228.525238       No
# 2                  2  LZ68649  Washington             14947.917300       No
# 3                  3  XL78013      Oregon             22332.439460      Yes
# 4                  4  QA50777      Oregon              9025.067525       No
# ...              ...      ...         ...                      ...      ...
# 10905          10905  FE99816      Nevada             15563.369440       No
# 10906          10906  KX53892      Oregon              5259.444853       No
# 10907          10907  TL39050     Arizona             23893.304100       No
# 10908          10908  WA60547  California             11971.977650       No
# 10909          10909  IV32877         NaN              6857.519928      NaN
#
# ...

# %%
#to find catgorical and numeric data
#df.select_dtypes(include=['category','int','float']).dtypes

print('original data and its length are as folows:')
cols = data.columns
cols
display(cols)
display(len(cols))

print('numeric data and its length are as folows:')
num_cols = data._get_numeric_data().columns
display(num_cols)
display(len(num_cols))


catergorical_data = list(set(cols) - set(num_cols))
catergorical_data
# Out:
# original data and its length are as folows:
# Index(['Serial Number', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')
# 26
# numeric data and its length are as folows:
# Index(['Serial Number', 'Customer Lifetime Value', 'Income',
#        'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Total Claim Amount'],
#       dtype='object')
# 9
# ['Renew Offer Type',
#  'Customer',
#  'Response',
# ...

# %%
# dealing with NaN
# first I will findout the number of missing values in the categorical data
#the response couloumn has values Nan, Yes or no


display(data['Response'].unique())
display(data['Response'].value_counts())

data['Response'].value_counts(dropna=False) # Use dropna=False to also display the amount of NA's

# I will replace the NaN value with that of has highest number of frequency value
data['Response'] = data['Response'].fillna('No')
print('after replacing')
display(data['Response'].unique())
display(data['Response'].value_counts())
#bool_series = pd.isnull(data["Response"])

# filtering data
# displaying data only with response = NaN
#print('displaying data only with response = NaN')
##display(data[bool_series])
# Out:
# array(['No', 'Yes'], dtype=object)
# No     9444
# Yes    1466
# Name: Response, dtype: int64
# after replacing
# array(['No', 'Yes'], dtype=object)
# No     9444
# Yes    1466
# Name: Response, dtype: int64

# %%
# i scout for some more of redundant values in categorical sets
data.head(30)
data.tail(30)

#From visual inspection i see NaN in Vehicle type coloumn
#so I clean some more

display(data['Vehicle Type'].unique())
display(data['Vehicle Type'].value_counts())
len(data[data['Vehicle Type'].isna()==True])  # number of missing values
data['Vehicle Type'].value_counts(dropna=False) # Use dropna=False to also display the amount of NA's

#output
#NaN    5482
#A      5428
# so we put everything as an 'A' value

data['Vehicle Type'] = data['Vehicle Type'].fillna('No')
# Out:
# array([nan, 'A'], dtype=object)
# A    5428
# Name: Vehicle Type, dtype: int64

# %%
# lets remove some whitespaces in the dataframe on all the categorical coloumns
#str. strip()


for coloumns in range (len(catergorical_data)):
    input_col = catergorical_data[coloumns]
    data['input_col'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'input_col'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
